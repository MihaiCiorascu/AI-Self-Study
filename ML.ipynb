# %% [markdown]
# <a href="https://colab.research.google.com/github/MihaiCiorascu/AI-Self-Study/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/loan_train_data.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['ApplicantIncome']
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
df['ApplicantIncome'] * 2
# Out:
# 0      11698
# 1       9166
# 2       6000
# 3       5166
# 4      12000
#        ...
# 609     5800
# 610     8212
# 611    16144
# 612    15166
# 613     9166
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
df['ApplicantIncome'] > 5000
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 609    False
# 610    False
# 611     True
# 612     True
# 613    False
# Name: ApplicantIncome, Length: 614, dtype: bool

# %%
df['ApplicantIncome'].loc[df['ApplicantIncome'] > 5000]
# Out:
# 0       5849
# 4       6000
# 5       5417
# 9      12841
# 20      7660
#        ...
# 599     5780
# 602     5703
# 604    12000
# 611     8072
# 612     7583
# Name: ApplicantIncome, Length: 191, dtype: int64

# %%
df['Property_Area']
# Out:
# 0          Urban
# 1          Rural
# 2          Urban
# 3          Urban
# 4          Urban
#          ...
# 609        Rural
# 610        Rural
# 611        Urban
# 612        Urban
# 613    Semiurban
# Name: Property_Area, Length: 614, dtype: object

# %%
df['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
plt.bar([0, 1, 2], df['Property_Area'].value_counts())
# Out:
# <BarContainer object of 3 artists>

# %%
df['ApplicantIncome']
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
plt.hist(df['ApplicantIncome'])
# Out:
# (array([533.,  59.,  15.,   0.,   4.,   0.,   1.,   1.,   0.,   1.]),
#  array([  150.,  8235., 16320., 24405., 32490., 40575., 48660., 56745.,
#         64830., 72915., 81000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['ApplicantIncome'], bins=20)
# Out:
# (array([353., 180.,  44.,  15.,  12.,   3.,   0.,   0.,   1.,   3.,   0.,
#           0.,   1.,   0.,   0.,   1.,   0.,   0.,   0.,   1.]),
#  array([  150. ,  4192.5,  8235. , 12277.5, 16320. , 20362.5, 24405. ,
#         28447.5, 32490. , 36532.5, 40575. , 44617.5, 48660. , 52702.5,
#         56745. , 60787.5, 64830. , 68872.5, 72915. , 76957.5, 81000. ]),
#  <BarContainer object of 20 artists>)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df['GE'] = 0

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.loc[df['Gender'] == 'Female', 'GE'] = 1
df.loc[df['Gender'] == 'Male', 'GE'] = 2
df.loc[df['Gender'] == 'Nan', 'GE'] = 0

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.drop(columns=['Loan_ID', 'Gender'], inplace=True)

# %%
df
# Out:
#     Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0        No          0      Graduate            No             5849
# 1       Yes          1      Graduate            No             4583
# 2       Yes          0      Graduate           Yes             3000
# 3       Yes          0  Not Graduate            No             2583
# 4        No          0      Graduate            No             6000
# ..      ...        ...           ...           ...              ...
# 609      No          0      Graduate            No             2900
# 610     Yes         3+      Graduate            No             4106
# 611     Yes          1      Graduate            No             8072
# 612     Yes          2      Graduate            No             7583
# 613      No          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# ...

# %%
df['Married'].value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
df['Married'] = df['Married'].map({'No': 0, 'Yes': 1})

# %%
df
# Out:
#      Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0        0.0          0      Graduate            No             5849
# 1        1.0          1      Graduate            No             4583
# 2        1.0          0      Graduate           Yes             3000
# 3        1.0          0  Not Graduate            No             2583
# 4        0.0          0      Graduate            No             6000
# ..       ...        ...           ...           ...              ...
# 609      0.0          0      Graduate            No             2900
# 610      1.0         3+      Graduate            No             4106
# 611      1.0          1      Graduate            No             8072
# 612      1.0          2      Graduate            No             7583
# 613      0.0          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
df['Dependents']
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 609     0
# 610    3+
# 611     1
# 612     2
# 613     0
# Name: Dependents, Length: 614, dtype: object

# %%
df['Dependents'].loc[0]
# Out:
# '0'

# %% [markdown]
# So Dependents column has Strings, not Integers

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
df['Dependents'] = df['Dependents'].map({'0': 0, '1': 1, '2': 2, '3+': 3})

# %%
df
# Out:
#      Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0        0.0         0.0      Graduate            No             5849
# 1        1.0         1.0      Graduate            No             4583
# 2        1.0         0.0      Graduate           Yes             3000
# 3        1.0         0.0  Not Graduate            No             2583
# 4        0.0         0.0      Graduate            No             6000
# ..       ...         ...           ...           ...              ...
# 609      0.0         0.0      Graduate            No             2900
# 610      1.0         3.0      Graduate            No             4106
# 611      1.0         1.0      Graduate            No             8072
# 612      1.0         2.0      Graduate            No             7583
# 613      0.0         0.0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# ...

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df['Education'] = df['Education'].map({'Graduate': 1, 'Not Graduate': 0})

# %%
df
# Out:
#      Married  Dependents  Education Self_Employed  ApplicantIncome  \
# 0        0.0         0.0          1            No             5849
# 1        1.0         1.0          1            No             4583
# 2        1.0         0.0          1           Yes             3000
# 3        1.0         0.0          0            No             2583
# 4        0.0         0.0          1            No             6000
# ..       ...         ...        ...           ...              ...
# 609      0.0         0.0          1            No             2900
# 610      1.0         3.0          1            No             4106
# 611      1.0         1.0          1            No             8072
# 612      1.0         2.0          1            No             7583
# 613      0.0         0.0          1           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# ...

# %%
df['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns=['Property_Area'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Married                  611 non-null    float64
#  1   Dependents               599 non-null    float64
#  2   Education                614 non-null    int64
#  3   Self_Employed            582 non-null    object
#  4   ApplicantIncome          614 non-null    int64
#  5   CoapplicantIncome        614 non-null    float64
#  6   LoanAmount               614 non-null    float64
#  7   Loan_Amount_Term         614 non-null    float64
#  8   Credit_History           614 non-null    float64
#  9   Loan_Status              614 non-null    object
#  10  GE                       614 non-null    int64
#  11  Property_Area_Rural      614 non-null    bool
#  12  Property_Area_Semiurban  614 non-null    bool
#  13  Property_Area_Urban      614 non-null    bool
# ...

# %%
df['LoanAmount']
# Out:
# 0      146.412162
# 1      128.000000
# 2       66.000000
# 3      120.000000
# 4      141.000000
#           ...
# 609     71.000000
# 610     40.000000
# 611    253.000000
# 612    187.000000
# 613    133.000000
# Name: LoanAmount, Length: 614, dtype: float64

# %%
df['LoanAmount'].mean()
# Out:
# np.float64(146.41216216216216)

# %%
df['LoanAmount'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Name: LoanAmount, Length: 614, dtype: bool

# %%
df.loc[df['LoanAmount'].isna(), 'LoanAmount'] = df['LoanAmount'].mean()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Married                  611 non-null    float64
#  1   Dependents               599 non-null    float64
#  2   Education                614 non-null    int64
#  3   Self_Employed            582 non-null    object
#  4   ApplicantIncome          614 non-null    int64
#  5   CoapplicantIncome        614 non-null    float64
#  6   LoanAmount               614 non-null    float64
#  7   Loan_Amount_Term         614 non-null    float64
#  8   Credit_History           614 non-null    float64
#  9   Loan_Status              614 non-null    object
#  10  GE                       614 non-null    int64
#  11  Property_Area_Rural      614 non-null    bool
#  12  Property_Area_Semiurban  614 non-null    bool
#  13  Property_Area_Urban      614 non-null    bool
# ...

# %%
df.loc[df['Loan_Amount_Term'].isna(), 'Loan_Amount_Term'] = df['Loan_Amount_Term'].mean()

# %%
df.loc[df['Credit_History'].isna(), 'Credit_History'] = df['Credit_History'].mean()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Married                  611 non-null    float64
#  1   Dependents               599 non-null    float64
#  2   Education                614 non-null    int64
#  3   Self_Employed            582 non-null    object
#  4   ApplicantIncome          614 non-null    int64
#  5   CoapplicantIncome        614 non-null    float64
#  6   LoanAmount               614 non-null    float64
#  7   Loan_Amount_Term         614 non-null    float64
#  8   Credit_History           614 non-null    float64
#  9   Loan_Status              614 non-null    object
#  10  GE                       614 non-null    int64
#  11  Property_Area_Rural      614 non-null    bool
#  12  Property_Area_Semiurban  614 non-null    bool
#  13  Property_Area_Urban      614 non-null    bool
# ...

# %%
df
# Out:
#      Married  Dependents  Education Self_Employed  ApplicantIncome  \
# 0        0.0         0.0          1            No             5849
# 1        1.0         1.0          1            No             4583
# 2        1.0         0.0          1           Yes             3000
# 3        1.0         0.0          0            No             2583
# 4        0.0         0.0          1            No             6000
# ..       ...         ...        ...           ...              ...
# 609      0.0         0.0          1            No             2900
# 610      1.0         3.0          1            No             4106
# 611      1.0         1.0          1            No             8072
# 612      1.0         2.0          1            No             7583
# 613      0.0         0.0          1           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  146.412162             360.0             1.0
# ...

# %%
X = df[ [
    'Married',
    'Dependents',
    'Education',
    'ApplicantIncome',
    'CoapplicantIncome',
    'LoanAmount',
    'Loan_Amount_Term',
    'Credit_History',
    'Property_Area_Rural',
    'Property_Area_Semiurban',
    'Property_Area_Urban'] ]

X
# Out:
#      Married  Dependents  Education  ApplicantIncome  CoapplicantIncome  \
# 0        0.0         0.0          1             5849                0.0
# 1        1.0         1.0          1             4583             1508.0
# 2        1.0         0.0          1             3000                0.0
# 3        1.0         0.0          0             2583             2358.0
# 4        0.0         0.0          1             6000                0.0
# ..       ...         ...        ...              ...                ...
# 609      0.0         0.0          1             2900                0.0
# 610      1.0         3.0          1             4106                0.0
# 611      1.0         1.0          1             8072              240.0
# 612      1.0         2.0          1             7583                0.0
# 613      0.0         0.0          1             4583                0.0
#
#      LoanAmount  Loan_Amount_Term  Credit_History  Property_Area_Rural  \
# ...

# %%
X.loc[X['Dependents'].isna(), 'Dependents'] = df['Dependents'].mode()[0]

# %%
X.loc[X['Married'].isna(), 'Married'] = df['Married'].mode()[0]

# %%
y = df['Loan_Status'].map({'Y': 1, 'N': 0})
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Married                  614 non-null    float64
#  1   Dependents               614 non-null    float64
#  2   Education                614 non-null    int64
#  3   ApplicantIncome          614 non-null    int64
#  4   CoapplicantIncome        614 non-null    float64
#  5   LoanAmount               614 non-null    float64
#  6   Loan_Amount_Term         614 non-null    float64
#  7   Credit_History           614 non-null    float64
#  8   Property_Area_Rural      614 non-null    bool
#  9   Property_Area_Semiurban  614 non-null    bool
#  10  Property_Area_Urban      614 non-null    bool
# dtypes: bool(3), float64(6), int64(2)
# memory usage: 40.3 KB

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()

model.fit(X, y)
# Out:
# KNeighborsClassifier()

# %%
model.score(X, y)
# Out:
# 0.7296416938110749

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

model.fit(X, y)

model.score(X, y)
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
model = RandomForestClassifier()

model.fit(X_train, y_train)

print(model.score(X_train, y_train))
print(model.score(X_test, y_test))
# Out:
# 1.0
# 0.8064516129032258
